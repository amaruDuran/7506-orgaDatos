# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
df_volvera = pd.read_csv("tp-2020-2c-train-cols1.csv")
df_volvera
# Out:
#      id_usuario  volveria
# 0           117         0
# 1           658         0
# 2           794         0
# 3           455         0
# 4           173         1
# ..          ...       ...
# 796         448         1
# 797         636         1
# 798         848         0
# 799         304         1
# 800         385         0
#
# [801 rows x 2 columns]

# %%
#verifico que no tenga datos en null ó sin completar
df_volvera.count()
# Out:
# id_usuario    801
# volveria      801
# dtype: int64

# %%
df_usuario = pd.read_csv("tp-2020-2c-train-cols2.csv")
df_usuario
# Out:
#     tipo_de_sala                    nombre  id_usuario  genero  edad  amigos  \
# 0             4d        Señor Camilo Pedro         117  hombre  73.5       0
# 1             4d    Señora Raquel Angelica         658   mujer  35.0       1
# 2         normal    Señor Antonio Federico         794  hombre   NaN       0
# 3             4d   Señor Osvaldo Aureliano         455  hombre   NaN       0
# 4             4d     Señorita Rita Eudosia         173   mujer   4.0       1
# ..           ...                       ...         ...     ...   ...     ...
# 796       normal    Señor Bernardo Melesio         448  hombre  37.0       0
# 797           3d   Señorita Lidia Catalina         636   mujer  31.0       0
# 798           4d      Señor Arturo Antenor         848  hombre  38.0       0
# 799           3d  Señorita Natividad Sofia         304   mujer   NaN       0
# 800           4d   Señor Isidoro Sebastian         385  hombre   NaN       0
#
#      parientes id_ticket  precio_ticket      fila        nombre_sede
# 0            0    59258;              1       NaN    fiumark_quilmes
# 1            1    586:6;              2       NaN    fiumark_quilmes
# 2            0  RE"39822              3       NaN  fiumark_chacarita
# 3            0  C17"4:39              1       NaN    fiumark_palermo
# 4            1    569964              2       NaN    fiumark_palermo
# ..         ...       ...            ...       ...                ...
# 796          0    3359;6              3       NaN    fiumark_palermo
# 797          0    45988:              2       NaN    fiumark_palermo
# 798          0    56;435              1       NaN  fiumark_chacarita
# 799          0    4487;5              2  adelante    fiumark_quilmes
# 800          0    56;449              1       NaN    fiumark_palermo
#
# [801 rows x 11 columns]

# %%
# calculo el procentaje de filas con valor nulo son mayores al 75 porciento, entonces decido quitar la columna fila de mi primera consideración de datos.
df_usuario.fila.isnull().mean() * 100
# Out:
# 77.90262172284645

# %%
#elimino la columna fila de memoria.
df_usuarioClean = df_usuario.drop(columns=['fila'])
df_usuarioClean
# Out:
#     tipo_de_sala                    nombre  id_usuario  genero  edad  amigos  \
# 0             4d        Señor Camilo Pedro         117  hombre  73.5       0
# 1             4d    Señora Raquel Angelica         658   mujer  35.0       1
# 2         normal    Señor Antonio Federico         794  hombre   NaN       0
# 3             4d   Señor Osvaldo Aureliano         455  hombre   NaN       0
# 4             4d     Señorita Rita Eudosia         173   mujer   4.0       1
# ..           ...                       ...         ...     ...   ...     ...
# 796       normal    Señor Bernardo Melesio         448  hombre  37.0       0
# 797           3d   Señorita Lidia Catalina         636   mujer  31.0       0
# 798           4d      Señor Arturo Antenor         848  hombre  38.0       0
# 799           3d  Señorita Natividad Sofia         304   mujer   NaN       0
# 800           4d   Señor Isidoro Sebastian         385  hombre   NaN       0
#
#      parientes id_ticket  precio_ticket        nombre_sede
# 0            0    59258;              1    fiumark_quilmes
# 1            1    586:6;              2    fiumark_quilmes
# 2            0  RE"39822              3  fiumark_chacarita
# 3            0  C17"4:39              1    fiumark_palermo
# 4            1    569964              2    fiumark_palermo
# ..         ...       ...            ...                ...
# 796          0    3359;6              3    fiumark_palermo
# 797          0    45988:              2    fiumark_palermo
# 798          0    56;435              1  fiumark_chacarita
# 799          0    4487;5              2    fiumark_quilmes
# 800          0    56;449              1    fiumark_palermo
#
# [801 rows x 10 columns]

# %%
#verifico que no modifica nada del archivo original
df_nuevo = pd.read_csv('tp-2020-2c-train-cols2.csv')
df_nuevo
# Out:
#     tipo_de_sala                    nombre  id_usuario  genero  edad  amigos  \
# 0             4d        Señor Camilo Pedro         117  hombre  73.5       0
# 1             4d    Señora Raquel Angelica         658   mujer  35.0       1
# 2         normal    Señor Antonio Federico         794  hombre   NaN       0
# 3             4d   Señor Osvaldo Aureliano         455  hombre   NaN       0
# 4             4d     Señorita Rita Eudosia         173   mujer   4.0       1
# ..           ...                       ...         ...     ...   ...     ...
# 796       normal    Señor Bernardo Melesio         448  hombre  37.0       0
# 797           3d   Señorita Lidia Catalina         636   mujer  31.0       0
# 798           4d      Señor Arturo Antenor         848  hombre  38.0       0
# 799           3d  Señorita Natividad Sofia         304   mujer   NaN       0
# 800           4d   Señor Isidoro Sebastian         385  hombre   NaN       0
#
#      parientes id_ticket  precio_ticket      fila        nombre_sede
# 0            0    59258;              1       NaN    fiumark_quilmes
# 1            1    586:6;              2       NaN    fiumark_quilmes
# 2            0  RE"39822              3       NaN  fiumark_chacarita
# 3            0  C17"4:39              1       NaN    fiumark_palermo
# 4            1    569964              2       NaN    fiumark_palermo
# ..         ...       ...            ...       ...                ...
# 796          0    3359;6              3       NaN    fiumark_palermo
# 797          0    45988:              2       NaN    fiumark_palermo
# 798          0    56;435              1       NaN  fiumark_chacarita
# 799          0    4487;5              2  adelante    fiumark_quilmes
# 800          0    56;449              1       NaN    fiumark_palermo
#
# [801 rows x 11 columns]

# %%
# se me ocurre unir ambos DataFrame con el objetivo de poder operar con un único data frame que me permita manejar 
# las distintas variables de df_usuario que hacen a la columna volveria.
df_usuarioClean.set_index('id_usuario')
df_usuarioClean
# Out:
#     tipo_de_sala                    nombre  id_usuario  genero  edad  amigos  \
# 0             4d        Señor Camilo Pedro         117  hombre  73.5       0
# 1             4d    Señora Raquel Angelica         658   mujer  35.0       1
# 2         normal    Señor Antonio Federico         794  hombre   NaN       0
# 3             4d   Señor Osvaldo Aureliano         455  hombre   NaN       0
# 4             4d     Señorita Rita Eudosia         173   mujer   4.0       1
# ..           ...                       ...         ...     ...   ...     ...
# 796       normal    Señor Bernardo Melesio         448  hombre  37.0       0
# 797           3d   Señorita Lidia Catalina         636   mujer  31.0       0
# 798           4d      Señor Arturo Antenor         848  hombre  38.0       0
# 799           3d  Señorita Natividad Sofia         304   mujer   NaN       0
# 800           4d   Señor Isidoro Sebastian         385  hombre   NaN       0
#
#      parientes id_ticket  precio_ticket        nombre_sede
# 0            0    59258;              1    fiumark_quilmes
# 1            1    586:6;              2    fiumark_quilmes
# 2            0  RE"39822              3  fiumark_chacarita
# 3            0  C17"4:39              1    fiumark_palermo
# 4            1    569964              2    fiumark_palermo
# ..         ...       ...            ...                ...
# 796          0    3359;6              3    fiumark_palermo
# 797          0    45988:              2    fiumark_palermo
# 798          0    56;435              1  fiumark_chacarita
# 799          0    4487;5              2    fiumark_quilmes
# 800          0    56;449              1    fiumark_palermo
#
# [801 rows x 10 columns]

# %%
df_usuarioClean = df_usuarioClean.join(df_volvera.set_index('id_usuario'), on='id_usuario', how='inner').set_index('id_usuario')

# %%
df_usuarioClean
# Out:
#            tipo_de_sala                    nombre  genero  edad  amigos  \
# id_usuario
# 117                  4d        Señor Camilo Pedro  hombre  73.5       0
# 658                  4d    Señora Raquel Angelica   mujer  35.0       1
# 794              normal    Señor Antonio Federico  hombre   NaN       0
# 455                  4d   Señor Osvaldo Aureliano  hombre   NaN       0
# 173                  4d     Señorita Rita Eudosia   mujer   4.0       1
# ...                 ...                       ...     ...   ...     ...
# 448              normal    Señor Bernardo Melesio  hombre  37.0       0
# 636                  3d   Señorita Lidia Catalina   mujer  31.0       0
# 848                  4d      Señor Arturo Antenor  hombre  38.0       0
# 304                  3d  Señorita Natividad Sofia   mujer   NaN       0
# 385                  4d   Señor Isidoro Sebastian  hombre   NaN       0
#
#             parientes id_ticket  precio_ticket        nombre_sede  volveria
# id_usuario
# 117                 0    59258;              1    fiumark_quilmes         0
# 658                 1    586:6;              2    fiumark_quilmes         0
# 794                 0  RE"39822              3  fiumark_chacarita         0
# 455                 0  C17"4:39              1    fiumark_palermo         0
# 173                 1    569964              2    fiumark_palermo         1
# ...               ...       ...            ...                ...       ...
# 448                 0    3359;6              3    fiumark_palermo         1
# 636                 0    45988:              2    fiumark_palermo         1
# 848                 0    56;435              1  fiumark_chacarita         0
# 304                 0    4487;5              2    fiumark_quilmes         1
# 385                 0    56;449              1    fiumark_palermo         0
#
# [801 rows x 10 columns]

# %%
df_usuarioClean.isnull().sum()
# Out:
# tipo_de_sala       0
# nombre             0
# genero             0
# edad             160
# amigos             0
# parientes          0
# id_ticket          0
# precio_ticket      0
# nombre_sede        2
# volveria           0
# dtype: int64

# %%
df_usuarioClean.loc[df_usuarioClean.volveria == 1].count()
# Out:
# tipo_de_sala     307
# nombre           307
# genero           307
# edad             261
# amigos           307
# parientes        307
# id_ticket        307
# precio_ticket    307
# nombre_sede      305
# volveria         307
# dtype: int64

# %%
df_usuarioClean.loc[(df_usuarioClean.edad > 25) & (df_usuarioClean.edad < 33) & (df_usuarioClean.volveria == 1)].count()
# Out:
# tipo_de_sala     53
# nombre           53
# genero           53
# edad             53
# amigos           53
# parientes        53
# id_ticket        53
# precio_ticket    53
# nombre_sede      53
# volveria         53
# dtype: int64

# %%
df_usuarioClean.loc[(df_usuarioClean.edad > 25) & (df_usuarioClean.edad < 33)]
# Out:
#            tipo_de_sala                     nombre  genero  edad  amigos  \
# id_usuario
# 91                   4d      Señor Carlos Gregorio  hombre  32.0       0
# 90                   4d    Señor Ernesto Reginaldo  hombre  27.0       0
# 510                  4d  Señor Rubens Carlos Randy  hombre  29.0       0
# 881                  3d     Señora Ana Rosa Esilda   mujer  28.0       0
# 247                  4d       Señorita Marta Nilda   mujer  28.0       0
# ...                 ...                        ...     ...   ...     ...
# 730                  4d   Señorita Josefa Agripina   mujer  28.0       1
# 342              normal   Señorita Leonilda Emilia   mujer  27.0       3
# 76                   4d         Señor Rodolfo Hugo  hombre  28.0       0
# 865                  3d           Señor Julio Aldo  hombre  27.0       0
# 636                  3d    Señorita Lidia Catalina   mujer  31.0       0
#
#             parientes         id_ticket  precio_ticket      nombre_sede  \
# id_usuario
# 91                  0            565498              1  fiumark_palermo
# 90                  0            565497              1  fiumark_palermo
# 510                 0              3823              6  fiumark_palermo
# 881                 1            452655              3  fiumark_palermo
# 247                 0            569293              1  fiumark_palermo
# ...               ...               ...            ...              ...
# 730                 0  UVQP1Q40"5323493              1  fiumark_palermo
# 342                 2             3;;72             26  fiumark_palermo
# 76                  0            56:345              1  fiumark_palermo
# 865                 0            455:88              2  fiumark_palermo
# 636                 0            45988:              2  fiumark_palermo
#
#             volveria
# id_usuario
# 91                 0
# 90                 0
# 510                1
# 881                1
# 247                0
# ...              ...
# 730                0
# 342                1
# 76                 0
# 865                0
# 636                1
#
# [136 rows x 10 columns]

# %%
df_quilmes = df_usuarioClean.loc[df_usuarioClean.nombre_sede == 'fiumark_quilmes']
df_palermo = df_usuarioClean.loc[df_usuarioClean.nombre_sede == 'fiumark_palermo']
df_chacarita = df_usuarioClean.loc[df_usuarioClean.nombre_sede == 'fiumark_chacarita']
"""
#existen sedes sin nombre, entonces las elimino del data frame original para evitar inconsistencias.
df_usuarioClean.loc[ (df_usuarioClean.nombre_sede != 'fiumark_quilmes') & (df_usuarioClean.nombre_sede != 'fiumark_palermo') & (df_usuarioClean.nombre_sede != 'fiumark_chacarita')]

# al "plotear" el df me salen los nombres de labels principales por id y los borro del df
df_usuarioClean.drop(labels=[830,62], inplace=True)
"""

df_quilmes.loc[df_quilmes.volveria == 1].count() / df_quilmes.count()
# Out:
# tipo_de_sala     0.380282
# nombre           0.380282
# genero           0.380282
# edad             0.307692
# amigos           0.380282
# parientes        0.380282
# id_ticket        0.380282
# precio_ticket    0.380282
# nombre_sede      0.380282
# volveria         0.380282
# dtype: float64

# %%
df_palermo.loc[df_palermo.volveria == 1].count() / df_palermo.count()
# Out:
# tipo_de_sala     0.336788
# nombre           0.336788
# genero           0.336788
# edad             0.362903
# amigos           0.336788
# parientes        0.336788
# id_ticket        0.336788
# precio_ticket    0.336788
# nombre_sede      0.336788
# volveria         0.336788
# dtype: float64

# %%
df_chacarita.loc[df_chacarita.volveria == 1].count() / df_chacarita.count()
# Out:
# tipo_de_sala     0.557047
# nombre           0.557047
# genero           0.557047
# edad             0.606838
# amigos           0.557047
# parientes        0.557047
# id_ticket        0.557047
# precio_ticket    0.557047
# nombre_sede      0.557047
# volveria         0.557047
# dtype: float64

# %%
df_usuarioClean[ ['nombre_sede'] ].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='nombre_sede'>

# %%
def porcentajeVolveria(unAgrupamiento):
    return (unAgrupamiento == 1).mean() * 100.0

def porcentajeNOVolveria(unAgrupamiento):
    return (unAgrupamiento == 0).mean() * 100.0

df_agrupados_por_sede = df_usuarioClean.groupby(by='nombre_sede').agg(
    {
        "volveria" : porcentajeVolveria,
    }
)

df_agrupados_por_sede.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='nombre_sede'>

# %%
df_agrupados_por_sede = df_usuarioClean.groupby('nombre_sede').agg(list)


arrayNumpy = df_agrupados_por_sede.to_numpy()
hola = np.array(arrayNumpy)


hola[0][1]
# Out:
# ['Señor Antonio Federico',
#  'Señora Lidia Barbarita',
#  'Señora Yolanda Anita',
#  'Señor Lorenzo Segundo',
#  'Señor Balbino Humberto',
#  'Señor Alberto De',
#  'Señora Rosa Gabriela',
#  'Señor Arturo Mario',
#  'Señora Lucinda Imelda',
#  'Señorita Ramona Escobares',
#  'Señor Silvino',
#  'Señor Agustin Ruperto',
#  'Señorita America Palmira',
#  'Señora Antonia Negilda',
#  'Señor Inocencio Atanasio',
#  'Señor Segundo José',
#  'Señor Juan Martin',
#  'Señora Juana Ceriaca',
#  'Señorita Felisa Eduarda',
#  'Señor Fortunato Saul',
#  'Señor Juan Aquilino',
#  'Señor Celso Hector',
#  'Señorita Juana Pura',
#  'Señor David Edelmiro',
#  'Señora Benigna Clotilde',
#  'Señor Pedro Dionisio',
#  'Señor Ernesto Gustavo',
#  'Señorita Julia Domiciana',
#  'Señor Elidio Santiago',
#  'Señor Juan Dalmiro',
#  'Señora Elsa Rosalia',
#  'Señor Jacinto Pedro',
#  'Señora Fermina Eugenia',
#  'Señor Clemente Hugo',
#  'Señor Leonardo Ramon',
#  'Señor Fernando Lorenzo Martin',
#  'Señor Marcos German',
#  'Señorita Margarita Betsabe',
#  'Señor Salvador Ramón',
#  'Señorita Victoria Emma',
#  'Señor Pio',
#  'Señorita Carmen Ondina',
#  'Señor Ceferino Antonio',
#  'Señora Benigna Elena',
#  'Señor Luis Alejandro',
#  'Señora Reina Benita',
#  'Señorita Ernestina Lidia',
#  'Señor Antonio De La Cruz',
#  'Señora Gloria Renee',
#  'Señor Americo Santiago',
#  'Señor Luis Rufino',
#  'Señora Dionisia Olga',
#  'Señorita Mercedes Cruz',
#  'Señor Rodolfo Celedonio',
#  'Señor Segundo David',
#  'Señor Valentin Arturo',
#  'Señora Matilde Josefina Del Valle',
#  'Señor Marcelo Proto',
#  'Señor Osvaldo Ireneo',
#  'Señor David Prudencio',
#  'Señora Blanca Cesar',
#  'Señorita Irma Filiberta',
#  'Señorita Hilaria Francisca',
#  'Señor Alfonso Arcides',
#  'Señor Ricardo Esteban',
#  'Señorita Feliciana',
#  'Señor Roberto Lisalvo',
#  'Señorita Olga del Tránsito',
#  'Señora Lita Mimi',
#  'Señor José Héctor Alfredo',
#  'Señor Domingo Valentin',
#  'Señora Elvira Caroll',
#  'Señorita Felisa Fornarina',
#  'Señorita Nilda Enid',
#  'Señor Olegario Ramón',
#  'Señor Juan',
#  'Señor Ernesto Manuel',
#  'Señor Manuel Andres',
#  'Señorita Delia Adelina',
#  'Señorita Esmeralda Pura',
#  'Señor Saul Humberto',
#  'Señor Isidro Arnoldo',
#  'Señor Roberto Ludovico',
#  'Señorita Sara Nicasia',
#  'Señora Leonilda Vital',
#  'Señorita Pascuala Amada',
#  'Señor Carlos Elvio',
#  'Señora Nora Betty',
#  'Señorita Tomasa Rosa',
#  'Señorita Lilian Edith',
#  'Señora Bienvenida Del Transito',
#  'Señor Horacio Arnaldo',
#  'Señor Clemente Teodoro Benigno',
#  'Señor Emeterio de Jesus',
#  'Señorita Ana Aurora Remedio',
#  'Señor Osvaldo Germán',
#  'Señor Pedro Felix',
#  'Señor Bernardo Jorge',
#  'Señor Domingo Ensoriano',
#  'Señorita Josefa Alejandra',
#  'Señor Argentino Jesus',
#  'Señorita Lilia Noelia',
#  'Señora Amalia Olga Ilda',
#  'Señora Elia Laudelina',
#  'Señora Serafina Ana',
#  'Señor Juan Nicanor',
#  'Señor Leopoldo Esteban',
#  'Señor Manuel Nicanor',
#  'Señor Eleuterio Jorge',
#  'Señor Candido Gerardo',
#  'Señor Arturo Carlos',
#  'Señorita Isabel Lydia',
#  'Señor Hipolito Victoriano',
#  'Señor Pedro Miguel Fidel',
#  'Señorita Antonia Lilia',
#  'Señorita Justa Teodomina',
#  'Señora Filomena Rosa',
#  'Señor Roberto Vidal',
#  'Señor Adolfo Efrain',
#  'Señor Roque Tomas',
#  'Señorita Isidora Irmina',
#  'Señor Pascual Salomon',
#  'Señorita Pabla Petrona',
#  'Señor Rogelio Esteban',
#  'Señor Florencio Benito',
#  'Señora Catalina Elsa',
#  'Señor Victoriano',
#  'Señora Olga Elida',
#  'Señor Enrique Iriberto',
#  'Señora Mercedes Olimpia',
#  'Señora Bernardina Del Carmen',
#  'Señor Nicolás Rosendo',
#  'Señor Salvador Amabil',
#  'Señor Fernando Jesus',
#  'Señor Aurelio Francisco',
#  'Señora Blanca Flora',
#  'Señor Héctor Ernesto',
#  'Señora Esther Bibiana',
#  'Señor Saturnino Martiniano',
#  'Señora Delia Ethel',
#  'Señor Agustin Enrique',
#  'Señorita Elisa Eufemia',
#  'Señora Nadia',
#  'Señor Francisco Casimiro',
#  'Señorita Amanda Hilda',
#  'Señorita Amelia Noemi',
#  'Señor Francisco Aniceto',
#  'Señor Armando Nelson',
#  'Señor Arturo Antenor']

# %% [markdown]
# ### Analizo otras variables que se me ocurren: Ir con amigos y/o familiares

# %%
df_usuarioClean.loc[(df_usuarioClean.genero == 'mujer') & (df_usuarioClean.volveria == 0)]
# Out:
#            tipo_de_sala                     nombre genero  edad  amigos  \
# id_usuario
# 658                  4d     Señora Raquel Angelica  mujer  35.0       1
# 230                  4d  Señorita Anselma Josefina  mujer   NaN       3
# 768                  4d        Señorita Lucía Elba  mujer  33.5       0
# 855                  3d    Señora Carmen Greunisia  mujer  47.0       1
# 247                  4d       Señorita Marta Nilda  mujer  28.0       0
# ...                 ...                        ...    ...   ...     ...
# 504                  4d      Señorita Jacinta Olga  mujer  40.0       0
# 41                   4d         Señora Elva Blanca  mujer  43.0       1
# 730                  4d   Señorita Josefa Agripina  mujer  28.0       1
# 800                  4d      Señora Matilde Nelida  mujer  33.0       1
# 639                  4d       Señora Patricia Gina  mujer  44.0       0
#
#             parientes         id_ticket  precio_ticket      nombre_sede  \
# id_usuario
# 658                 1            586:6;              2  fiumark_quilmes
# 230                 1              6355              3  fiumark_palermo
# 768                 0            586:72              1  fiumark_quilmes
# 855                 0            466474              3  fiumark_palermo
# 247                 0            569293              1  fiumark_palermo
# ...               ...               ...            ...              ...
# 504                 0              6357              1  fiumark_palermo
# 41                  0              9768              1  fiumark_palermo
# 730                 0  UVQP1Q40"5323493              1  fiumark_palermo
# 800                 1            567995              3  fiumark_palermo
# 639                 5           53234;7              4  fiumark_palermo
#
#             volveria
# id_usuario
# 658                0
# 230                0
# 768                0
# 855                0
# 247                0
# ...              ...
# 504                0
# 41                 0
# 730                0
# 800                0
# 639                0
#
# [75 rows x 10 columns]

# %% [markdown]
# ### Agrupo entonces por Hombre y Mujer y ploteo los porcentajes de volver de cada genero.

# %%
df_usuarios_porGenero = df_usuarioClean.groupby(by=['genero']).agg(
    {
        'volveria' : porcentajeVolveria
    }
)

#df_usuarios_porGenero['no volveria'] = df_usuarios_porGenero['volveria'].apply(porcentajeNOVolveria)

df_usuarios_porGenero['no volveria'] = df_usuarioClean.groupby(by=['genero']).agg(
    {
        'volveria' : porcentajeNOVolveria
    }
)

df_usuarios_porGenero
# Out:
#          volveria  no volveria
# genero
# hombre  18.323587    81.676413
# mujer   73.958333    26.041667

# %% [markdown]
# ### Me fijo cuanta accuracy tenemos sin hacer ninguna partición

# %%
from sklearn.metrics import accuracy_score

#observo que la mayoría no vuelve.
pred = [1] * len(df_usuarioClean)
accuracy_score(df_usuarioClean.volveria, pred)
# Out:
# 0.383270911360799

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=[6.4 * 2 , 4.8], dpi=100)

df_usuario_volvera = df_usuarioClean[ df_usuarioClean.volveria == 1 ]

df_usuario_no_volvera = df_usuarioClean[ df_usuarioClean.volveria == 0 ]

df_usuario_volvera.edad.plot(kind = 'hist', ax=axes[0], xlim=df_usuarioClean.edad.min())

df_usuario_no_volvera.edad.plot(kind = 'hist', ax=axes[1], xlim=df_usuarioClean.edad.min())

axes[0].set_title("edad - volverian")
axes[0].set_xlabel("edad")

axes[1].set_title("edad - no volverian")
axes[1].set_xlabel("edad")

plt.show()

# %%
import seaborn as sns

plt.figure(dpi=100)
sns.countplot(data=df_usuarioClean, x='precio_ticket', hue='volveria')

plt.title("Cantidad por Precio de Ticket")import seaborn as sns

plt.figure(dpi=100)
sns.countplot(data=df_usuarioClean, x='precio_ticket', hue='volveria')

plt.title("Cantidad por Precio de Ticket")
# Out:
# Text(0.5, 1.0, 'Cantidad por Precio de Ticket')

# %%
import seaborn as sns

plt.figure(dpi=100)
sns.countplot(data=df_usuarioClean, x='tipo_de_sala', hue='volveria')

plt.title("Cantidad por Tipo de Sala")
# Out:
# Text(0.5, 1.0, 'Cantidad por Tipo de Sala')

# %%
df_usuarioClean[(df_usuarioClean.nombre_sede == 'fiumark_palermo') & 
                (df_usuarioClean.tipo_de_sala == '4d') & 
                (df_usuarioClean.genero == 'hombre') & 
                (df_usuarioClean.volveria == 1)]
# Out:
#            tipo_de_sala                        nombre  genero  edad  amigos  \
# id_usuario
# 510                  4d     Señor Rubens Carlos Randy  hombre  29.0       0
# 128                  4d         Señor Rodolfo Pascual  hombre  27.0       0
# 490                  4d        Señor Justino Sipriano  hombre  12.0       1
# 789                  4d             Señor Mateo Roque  hombre   4.0       1
# 205                  4d               Señor Candido J  hombre  21.0       0
# 221                  4d          Señor Antonio Máximo  hombre  19.0       0
# 392                  4d           Señor Enrique Heper  hombre  24.0       0
# 268                  4d          Señor Benito Higinio  hombre  28.0       1
# 272                  4d          Señor Eduardo Ovidio  hombre  28.0       0
# 693                  4d         Señor Gregorio Nestor  hombre   NaN       0
# 665                  4d   Señor Buenaventura Anacleto  hombre  23.0       1
# 108                  4d          Señor Marcelo Adolfo  hombre   NaN       0
# 644                  4d               Señor Abel Omar  hombre   NaN       0
# 75                   4d        Señor Rodolfo Dionisio  hombre  35.0       0
# 284                  4d     Señor Antonio Raul Felipe  hombre  22.0       0
# 262                  4d          Señor Manuel Teodoro  hombre   6.0       4
# 870                  4d         Señor Abraham Natalio  hombre   7.0       1
# 745                  4d           Señor Jorge Haroldo  hombre  34.0       0
# 147                  4d     Señor Jorge Elias Eduardo  hombre  30.0       0
# 822                  4d           Señor Facundo Roque  hombre  30.0       0
# 287                  4d         Señor Eduardo Honorio  hombre  33.0       0
# 839                  4d            Señor David Abdala  hombre  35.0       0
# 752                  4d    Señor Héctor Livio Eduardo  hombre   9.0       0
# 401                  4d         Señor Heriberto Pedro  hombre  42.0       0
# 580                  4d  Señor Pedro Nicanor  Antonio  hombre  35.0       0
# 445                  4d       Señor Olegario Gregorio  hombre   NaN       0
# 339                  4d            Señor Edgardo Hugo  hombre  48.0       0
# 805                  4d         Señor Enrique Rogelio  hombre  30.0       0
# 570                  4d        Señor Patricio Arcemio  hombre  35.0       0
# 415                  4d         Señor Anibal Humberto  hombre  47.0       0
#
#             parientes          id_ticket  precio_ticket      nombre_sede  \
# id_usuario
# 510                 0               3823              6  fiumark_palermo
# 128                 0            E"3958;              1  fiumark_palermo
# 490                 1         E0C0"59893              2  fiumark_palermo
# 789                 2          E0C0"4537              3  fiumark_palermo
# 205                 0           C17"5762              1  fiumark_palermo
# 221                 0    UQVQP1QS"5;42:;              1  fiumark_palermo
# 392                 0             572256              1  fiumark_palermo
# 268                 0             5692:5              1  fiumark_palermo
# 272                 0               NKPG              1  fiumark_palermo
# 693                 0               3823              6  fiumark_palermo
# 665                 0  UVQP1Q"40"53234:7              1  fiumark_palermo
# 108                 0             534;;3              1  fiumark_palermo
# 644                 0               3823              6  fiumark_palermo
# 75                  0               3823              6  fiumark_palermo
# 284                 0         C170"326:4              1  fiumark_palermo
# 262                 2             569299              4  fiumark_palermo
# 870                 1             569964              2  fiumark_palermo
# 745                 0  UVQP1Q"40"53234::              1  fiumark_palermo
# 147                 0             572265              1  fiumark_palermo
# 822                 0             5372;:              1  fiumark_palermo
# 287                 0             567996              1  fiumark_palermo
# 839                 0               3823              6  fiumark_palermo
# 752                 1             5;42;8              2  fiumark_palermo
# 401                 0  UVQP1Q"40"53234:;              1  fiumark_palermo
# 580                 0  UVQP1Q"40"53234:8              1  fiumark_palermo
# 445                 0              87528              1  fiumark_palermo
# 339                 0               97;:              1  fiumark_palermo
# 805                 0             5692:;              1  fiumark_palermo
# 570                 0             572639              1  fiumark_palermo
# 415                 0  UVQP1Q"40"532348;              1  fiumark_palermo
#
#             volveria
# id_usuario
# 510                1
# 128                1
# 490                1
# 789                1
# 205                1
# 221                1
# 392                1
# 268                1
# 272                1
# 693                1
# 665                1
# 108                1
# 644                1
# 75                 1
# 284                1
# 262                1
# 870                1
# 745                1
# 147                1
# 822                1
# 287                1
# 839                1
# 752                1
# 401                1
# 580                1
# 445                1
# 339                1
# 805                1
# 570                1
# 415                1

# %%
df_usuarioClean[(df_usuarioClean.nombre_sede == 'fiumark_palermo') & 
                (df_usuarioClean.tipo_de_sala == '4d') & 
                (df_usuarioClean.genero == 'mujer') & 
                (df_usuarioClean.volveria == 1)]
# Out:
#            tipo_de_sala                         nombre genero  edad  amigos  \
# id_usuario
# 173                  4d          Señorita Rita Eudosia  mujer   4.0       1
# 107                  4d        Señorita Alicia Augusta  mujer  24.0       0
# 11                   4d                 Señorita Sonia  mujer   7.0       1
# 26                   4d       Señora Rosalina Victoria  mujer  41.0       1
# 280                  4d         Señora Micaela Dominga  mujer  38.0       1
# 480                  4d        Señorita Inocencia Irma  mujer   5.0       0
# 143                  4d           Señora Lorenza Adela  mujer  27.0       1
# 185                  4d      Señorita Ermelinda Carmen  mujer   7.0       0
# 9                    4d           Señora Olga Cristina  mujer  30.0       0
# 484                  4d       Señora Francisca Vicenta  mujer  66.0       0
# 86                   4d             Señora Helena Dora  mujer  36.0       3
# 316                  4d        Señorita Lidia Pascuala  mujer  29.0       0
# 856                  4d            Señora Rosa Macrina  mujer  21.0       0
# 778                  4d  Señorita Magdalena Del Carmen  mujer   8.0       0
# 432                  4d    Señora Susana Beatriz Maria  mujer   NaN       1
# 555                  4d          Señorita Anselma Dina  mujer  25.0       0
# 217                  4d         Señorita Otilia Otilia  mujer  30.0       0
# 69                   4d        Señorita Lola Gertrudis  mujer  20.0       4
# 824                  4d          Señora Delfina Clelia  mujer  30.0       0
# 329                  4d              Señora Olga Lidia  mujer  34.0       1
# 3                    4d       Señorita Dominga Geralda  mujer  29.0       0
# 798                  4d             Señora Elena Telma  mujer  34.0       0
# 377                  4d          Señorita Nidia Amadea  mujer  25.0       0
# 193                  4d          Señorita Flora Liamar  mujer  22.0       1
# 678                  4d       Señorita Catalina Elvira  mujer  21.0       0
# 142                  4d          Señorita Livia Regina  mujer  25.0       0
# 560                  4d       Señora Delia Guillermina  mujer  39.0       1
# 348                  4d          Señora Angela Erminia  mujer   NaN       1
#
#             parientes         id_ticket  precio_ticket      nombre_sede  \
# id_usuario
# 173                 1            569964              2  fiumark_palermo
# 107                 0            565342              1  fiumark_palermo
# 11                  1           RR";76;              2  fiumark_palermo
# 26                  5            569299              4  fiumark_palermo
# 280                 1         E0C0"4895              2  fiumark_palermo
# 480                 1           53234;:              2  fiumark_palermo
# 143                 0  UVQP1Q40"532349;              2  fiumark_palermo
# 185                 2            537375              3  fiumark_palermo
# 9                   2            569964              2  fiumark_palermo
# 484                 0              6356              1  fiumark_palermo
# 86                  0           532349:              2  fiumark_palermo
# 316                 0            569692              1  fiumark_palermo
# 856                 1            5;42;3              1  fiumark_palermo
# 778                 0            586738              2  fiumark_palermo
# 432                 0            598786              2  fiumark_palermo
# 555                 0            5692:7              1  fiumark_palermo
# 217                 0  UVQP1Q40"53234:5              1  fiumark_palermo
# 69                  2           53234:3              1  fiumark_palermo
# 824                 1            5;42;8              2  fiumark_palermo
# 329                 1            5854;3              3  fiumark_palermo
# 3                   0  UVQP1Q40"53234:4              1  fiumark_palermo
# 798                 0            56;466              1  fiumark_palermo
# 377                 0            E"9299              1  fiumark_palermo
# 193                 0            572268              1  fiumark_palermo
# 678                 0              635:              1  fiumark_palermo
# 142                 0            5692:3              1  fiumark_palermo
# 560                 0            567794              2  fiumark_palermo
# 348                 0            5:8747              2  fiumark_palermo
#
#             volveria
# id_usuario
# 173                1
# 107                1
# 11                 1
# 26                 1
# 280                1
# 480                1
# 143                1
# 185                1
# 9                  1
# 484                1
# 86                 1
# 316                1
# 856                1
# 778                1
# 432                1
# 555                1
# 217                1
# 69                 1
# 824                1
# 329                1
# 3                  1
# 798                1
# 377                1
# 193                1
# 678                1
# 142                1
# 560                1
# 348                1
